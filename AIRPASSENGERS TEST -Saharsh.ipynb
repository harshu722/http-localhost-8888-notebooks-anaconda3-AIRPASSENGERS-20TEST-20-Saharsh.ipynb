# %%
import numpy as np
import pandas as pd
from datetime import datetime as dt
from statsmodels.tsa.stattools import adfuller,acf,pacf
from statsmodels.tsa.arima_model import ARIMA
import math
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15,6

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('AirPassengers.csv')

# %%
data['Month'].head()
# Out:
# 0    1949-01
# 1    1949-02
# 2    1949-03
# 3    1949-04
# 4    1949-05
# Name: Month, dtype: object

# %%
data['Month']=data['Month'].apply(lambda x: dt(int(x[:4]),int(x[5:]),15))
data  = data.set_index('Month')
data.head()
# Out:
#             #Passengers
# Month
# 1949-01-15          112
# 1949-02-15          118
# 1949-03-15          132
# 1949-04-15          129
# 1949-05-15          121

# %%
ts = data['#Passengers']

# %%
plt.plot(ts)

# %%
ts_log = np.log(ts)

# %%
def test_stationarity(timeseries):
    rolmean = timeseries.rolling(window=52,center=False).mean()
    rolstd = timeseries.rolling(window=52,center=False).std()
    
    orig = plt.plot(timeseries,color='blue', label='original')
    mean = plt.plot(rolmean,color='red',label='Rolling Mean')
    std = plt.plot(rolstd, color='black',label = 'Rolling std')
    plt.legend(loc='best')
    plt.title('Rolling Mean and standard Deviation')
    plt.show(block=False)
    
    print('Results of Dicky-Fuller Test:')
    dftest = adfuller(timeseries,autolag='AIC')
    dfoutput = pd.Series(dftest[0:4],index=['Test Statistic','p-value','#Lags Used',
                                             'Number of observations Used'])
    for key,value in dftest[4].items():
        dfoutput['critical Value (%s)'%key] = value
    print(dfoutput)

# %%
test_stationarity(data['#Passengers'])
# Out:
# Results of Dicky-Fuller Test:
# Test Statistic                   0.815369
# p-value                          0.991880
# #Lags Used                      13.000000
# Number of observations Used    130.000000
# critical Value (1%)             -3.481682
# critical Value (5%)             -2.884042
# critical Value (10%)            -2.578770
# dtype: float64

# %%
plt.plot(ts_log)

# %%
movingAverage = ts_log.rolling(window=12).mean()
movingSTD = ts_log.rolling(window=12).std()
plt.plot(ts_log)
plt.plot(movingAverage,color='red')

# %%
ts_log_mv_diff = ts_log - movingAverage
ts_log_mv_diff.head(12)

ts_log_mv_diff.dropna(inplace=True)
ts_log_mv_diff.head(10)
# Out:
# Month
# 1949-12-15   -0.065494
# 1950-01-15   -0.093449
# 1950-02-15   -0.007566
# 1950-03-15    0.099416
# 1950-04-15    0.052142
# 1950-05-15   -0.027529
# 1950-06-15    0.139881
# 1950-07-15    0.260184
# 1950-08-15    0.248635
# 1950-09-15    0.162937
# Name: #Passengers, dtype: float64

# %%
test_stationarity(ts_log_mv_diff)
# Out:
# Results of Dicky-Fuller Test:
# Test Statistic                  -3.162908
# p-value                          0.022235
# #Lags Used                      13.000000
# Number of observations Used    119.000000
# critical Value (1%)             -3.486535
# critical Value (5%)             -2.886151
# critical Value (10%)            -2.579896
# dtype: float64

# %% [markdown]
# ## Null hypothesis works
# ## stationarity check done
# ## -Saharsh

# %% [markdown]
# ## ROLLING STATISTICS

# %%
test_stationarity(data['#Passengers'])
# Out:
# Results of Dicky-Fuller Test:
# Test Statistic                   0.815369
# p-value                          0.991880
# #Lags Used                      13.000000
# Number of observations Used    130.000000
# critical Value (1%)             -3.481682
# critical Value (5%)             -2.884042
# critical Value (10%)            -2.578770
# dtype: float64

# %%
plt.plot(ts_log)

# %%
movingAverage = ts_log.rolling(window=12).mean()
movingSTD = ts_log.rolling(window=12).std()
plt.plot(ts_log)
plt.plot(movingAverage, color='red')

# %%
ts_log_mv_diff = ts_log - movingAverage
ts_log_mv_diff.head(12)

ts_log_mv_diff.dropna(inplace=True)
ts_log_mv_diff.head(10)
# Out:
# Month
# 1949-12-15   -0.065494
# 1950-01-15   -0.093449
# 1950-02-15   -0.007566
# 1950-03-15    0.099416
# 1950-04-15    0.052142
# 1950-05-15   -0.027529
# 1950-06-15    0.139881
# 1950-07-15    0.260184
# 1950-08-15    0.248635
# 1950-09-15    0.162937
# Name: #Passengers, dtype: float64

# %%
test_stationarity(ts_log_mv_diff)
# Out:
# Results of Dicky-Fuller Test:
# Test Statistic                  -3.162908
# p-value                          0.022235
# #Lags Used                      13.000000
# Number of observations Used    119.000000
# critical Value (1%)             -3.486535
# critical Value (5%)             -2.886151
# critical Value (10%)            -2.579896
# dtype: float64

# %%
plt.plot(np.arrange(0,11), acf(ts_log_mv_diff, nlags = 10))
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-7.96/np.sqrt(len(ts_log_mv_diff)),linestyle='--',color='gray')
plt.axhline(y=7.96/np.sqrt(len(ts_log_mv_diff)),linestyle='--',color='gray')
plt.title('Partial Autocorrelation Function')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4860\4204982535.py in <module>
# ----> 1 plt.plot(np.arrange(0,11), acf(ts_log_mv_diff, nlags = 10))
#       2 plt.axhline(y=0,linestyle='--',color='gray')
#       3 plt.axhline(y=-7.96/np.sqrt(len(ts_log_mv_diff)),linestyle='--',color='gray')
#       4 plt.axhline(y=7.96/np.sqrt(len(ts_log_mv_diff)),linestyle='--',color='gray')
#       5 plt.title('Partial Autocorrelation Function')
#
# ~\anaconda3\lib\site-packages\numpy\__init__.py in __getattr__(attr)
#     311                 return Tester
#     312
# --> 313             raise AttributeError("module {!r} has no attribute "
#     314                                  "{!r}".format(__name__, attr))
#     315
#
# AttributeError: module 'numpy' has no attribute 'arrange'

# %%
predictions_ARIMA_log = pd.Series(ts_log.iloc[0]; index=ts_log.index)
predictions_ARIMA_log = predictions_ARIMA_log.add(predictions_ARIMA_diff_cumsum,fill_value=0)
predictions_ARIMA_log.head()
# Out:
#   File "C:\Users\saharsh\AppData\Local\Temp\ipykernel_4860\3990609891.py", line 1
#     predictions_ARIMA_log = pd.Series(ts_log.iloc[0]; index=ts_log.index)
#                                                     ^
# SyntaxError: invalid syntax

# %%
predictions_ARIMA = np.exp(predictions_ARIMA_log)
plt.plot(ts)
plt.plot(predictions_ARIMA)
plt.title('RMSE: %.4f'% np.sqrt(sum((predictions_ARIMA-ts)**2)/len(ts)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4860\781328692.py in <module>
# ----> 1 predictions_ARIMA = np.exp(predictions_ARIMA_log)
#       2 plt.plot(ts)
#       3 plt.plot(predictions_ARIMA)
#       4 plt.title('RMSE: %.4f'% np.sqrt(sum((predictions_ARIMA-ts)**2)/len(ts)))
#
# NameError: name 'predictions_ARIMA_log' is not defined
